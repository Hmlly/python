# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Matplotlib
#
# codebase contains
# 1. high-level commands used mostly
# 1. low-level commands that ensure the control of every elements
#
# Figures are understood by hierarchical structure:
# 1. "state-machine environment" which is provided by the `matplotlib.pyplot` module
#     > Pyplot's state-machine environment behaves similarly to MATLAB and should be most familiar to users with MATLAB experience.
# 1. [Figure](https://matplotlib.org/3.1.1/api/figure_api.html)
# 1. [Axes](https://matplotlib.org/3.1.1/api/axes_api.html) 子图
# 1. [Axis](https://matplotlib.org/3.1.1/api/axis_api.html) x/y坐标轴的数据
# 1. [Artist](https://matplotlib.org/3.1.1/api/artist_api.html)
#
#
# All of plotting functions expect np.array or np.ma.masked_array as input. Classes that are 'array-like' such as pandas data objects and np.matrix may or may not work as intended. It is best to convert these to np.array objects prior to plotting.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 空图不显示
fig = plt.figure()  # an empty figure with no axes
fig.suptitle('No axes on this figure')  # Add a title so we know which it is
plt.show()

# %%
x = np.linspace(0, 2, 100)
# 指定图像大小
fig = plt.figure(figsize=(10,6))
# start
plt.plot(x, x, 'bo', label='linear')
plt.plot(x, x**2, 'r+', label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

# 登记线系列
plt.title("Simple Plot")
plt.legend()
# plt.legend(['a','b','c']) 

# end
plt.show()

# %%
print(fig)
# Out:
# Figure(720x432)

# %% [markdown]
# ## 子图

# %%
# 画 2x2 子图
# 返回整体 figure 和 子图矩阵
fig, axes_lst = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
print(fig)
print(axes_lst)
# Out:
# Figure(432x288)
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00000247DC38C1D0>
# ...

# %%
# 子图的画法
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig, ax = plt.subplots(2,2) # 2行2列
ax[0,0].plot(x, y)
ax[0,0].plot(x, -y)
plt.show()

# %%
# 自定义子图画法
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# which you would then use as:

data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker': 'x'})

# %%
# 使用相同的画法画不同的数据，形成多个子图
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10,6)) # 1行2列
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %% [markdown]
# ## An example to learn from matplotlib official site
#
# 1. for example, we want to play
#     - [Errorbar Subsample](https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/errorbar_subsample.html#sphx-glr-gallery-lines-bars-and-markers-errorbar-subsample-py)
#     Demo for the errorevery keyword to show data full accuracy data plots with few errorbars.

# %%
# Errorbar Subsample
import numpy as np
import matplotlib.pyplot as plt

# example data
x = np.arange(0.1, 4, 0.1)
y = np.exp(-x)

# example variable error bar values
yerr = 0.1 + 0.1 * np.sqrt(x)

# Now switch to a more OO interface to exercise more features.
fig, axs = plt.subplots(nrows=1, ncols=2, sharex=True)
ax = axs[0]
ax.errorbar(x, y, yerr=yerr)
ax.set_title('all errorbars')
ax.set_ylim(-1,1)
ax = axs[1]
ax.errorbar(x, y, yerr=yerr, errorevery=5)
ax.set_title('only every 5th errorbar')


fig.suptitle('Errorbar subsampling for better appearance')

plt.show()

# %% [markdown]
# # Seaborn
#
# More fancy codebase based on matplotlib
#
# 1. Statistical estimation and error bars¶
# 1. Figure-level and axes-level functions¶

# %%
import seaborn as sns
# 设置绘图风格-背景、网格线等
sns.set()

# %%
# Load a dataset from the online repository (requires internet).
# `name`.csv on https://github.com/mwaskom/seaborn-data
fmri = sns.load_dataset("fmri")

# %%
# Figure-level interface for drawing relational plots onto a FacetGrid.
# 将数据按照列 region 分组成不同平面（此处分为2组：parietal,frontal）
# 将数据按照列 event 分组成不同风格（此处分为2组：stim,cue）
sns.relplot(x="timepoint", y="signal", col="region",
            hue="event", style="event",
            kind="line", data=fmri);

# %%
print(type(fmri))
fmri.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# Load a dataset from the online repository (requires internet).
# `name`.csv on https://github.com/mwaskom/seaborn-data
tips = sns.load_dataset("tips")

# %%
sns.relplot(x="total_bill", y="tip", col="time",
            hue="smoker", style="smoker", size="size",
            data=tips);

# %%
# 使用seaborn 绘制子图，只需将子图数据sxes[0/1]传入函数s
import matplotlib.pyplot as plt
f, axes = plt.subplots(1, 2, sharey=True, figsize=(10, 6))
# 盒子
# Draw a box plot to show distributions with respect to categories
sns.boxplot(x="day", y="tip", data=tips, ax=axes[0])
# 散点
sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips, ax=axes[1]);

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# [seaborn heatmap](https://seaborn.pydata.org/examples/structured_heatmap.html)

# %%
import pandas as pd
import seaborn as sns
sns.set()

# Load the brain networks example dataset
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Select a subset of the networks
used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

# Create a categorical palette to identify the networks
network_pal = sns.husl_palette(8, s=.45)
network_lut = dict(zip(map(str, used_networks), network_pal))

# Convert the palette to vectors that will be drawn on the side of the matrix
networks = df.columns.get_level_values("network")
network_colors = pd.Series(networks, index=df.columns).map(network_lut)

# Draw the full plot
sns.clustermap(df.corr(), center=0, cmap="vlag",
               row_colors=network_colors, col_colors=network_colors,
               linewidths=.75, figsize=(13, 13))

# %% [markdown]
# ## 画散点图
# - 散点图
# ```python
# # matplotlib visualization library
# import matplotlib.pyplot as plt
# plt.scatter(x_values, y_values,….) #画散点图
# ```
# - 散点图矩阵
# ```python
# # Seaborn visualization library
# Import seaborn as sns
# sns.pairplot(df)#画散点矩阵图
# ```

# %% [markdown]
# ## 画线图
# - 直角坐标系
# ```python
# # matplotlib visualization library
# import matplotlib.pyplot as plt
# plt.plot(x_values, y_values,….) #画线图
# ```
# -极坐标系（雷达图、径向轴）
# ```python
# # matplotlib visualization library极坐标系实现
# import numpy as np
# import matplotlib.pyplot as plt
# angles=np.linspace(0,2*np.pi,dataLength,endpoint=False)
# angles=np.concatenate((angles,[angles[0]]))#闭合
# fig=plt.figure()
# ax=fig.add_subplot(111,polar=True)#polar参数
# ax.plot(angles,data,’bo-’,linewidth=2)#画线
# ax.fill(angles,)
# ```
#     - [Polar Demo](https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/polar_demo.html#sphx-glr-gallery-pie-and-polar-charts-polar-demo-py)

# %%
# Polar Demo
import numpy as np
import matplotlib.pyplot as plt

r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r

ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
ax.grid(True)

ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %% [markdown]
# ## 画区域图
# - 柱状图
#     - x和y两组数据，对应x轴和y轴（柱高）
# ```python
# # matplotlib visualization library
# import matplotlib.pyplot as plt
# plt.bar(x_values, y_values,….) #画柱状图
# ```
# - 直方图
#     - 统计x出现在某个分类的数量或频率
# ```python
# # matplotlib visualization library
# import matplotlib.pyplot as plt
# plt.hist(x,….) #画直方图
# ```
# - 饼图
#     - 统计x出现在某个分类的百分比
# ```python
# plt.pie(...) # 画饼图
# ```

# %%
# 画饼图
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
labels = ['娱乐','育儿','饮食','房贷','交通','其它']
sizes = [2,5,12,70,2,9]
explode = (0,0,0,0.1,0,0)
plt.pie(sizes,explode=explode,labels=labels,autopct='\
%1.1f%%',shadow=False,startangle=150)
plt.title("饼图示例-8月份家庭支出")
plt.show()

# %% [markdown]
# ## 其他
# - K线图
# - 盒型图
#     - 显示一组数据分散情况。
#     - 它能显示出一组数据的最大值、最小值、中位数、下四分位数及上四分位数。
#     - [小提琴图](https://seaborn.pydata.org/examples/simple_violinplots.html)
# - 地图
#     - 需要GIS数据
# - 色块图（热力图）
#     - 最大好处是，2 维画布上的空间利用率非常高。
#     - 特别适合用于直接对数据量较大的、相对原始的数据进行分析。
#     - github 每日提交统计图
# - 关系图
#     - 用于展现节点与节点之间的关系数据。
#     - 自然语言处理，知识图谱
# - 分块树图
#     - Treemap是一种常见的表达层级数据、树状数据的可视化形式。
#     - 主要采用面积的方式，便于突出展现出树的各个重要节点和占比。
# - 桑基图
#     - 桑基能量分流图，也叫桑基能量平衡图。
#     - 它是一种特定类型的流程图，图中延伸的分支的宽度对应数据流量的大小。

# %%
# 小提琴图
import numpy as np
import seaborn as sns

sns.set()

# Create a random dataset across several variables
rs = np.random.RandomState(0)
n, p = 40, 8
d = rs.normal(0, 2, (n, p))
d += np.log(np.arange(1, p + 1)) * -5 + 10

# Use cubehelix to get a custom sequential palette
pal = sns.cubehelix_palette(p, rot=-.5, dark=.3)

# Show each distribution with both violins and points
sns.violinplot(data=d, palette=pal, inner="points")

# %% [markdown]
# # 数据可视化工具
# - 最高端的JS库(D3、Echarts、highchart)
# - 主流的数据科学编程工具（R、Python等）
# - 人人都能上手的自助式BI工具（PowerBI、Tableau等）

# %% [markdown]
# ## [Tableau](https://www.tableau.com/zh-cn)
# - 可视化程序，软件容易上手
# - 每次都是实时查询数据，如果数据量大，会卡顿
# - 收费较高

# %% [markdown]
# ## D3
# - [Data-Driven Documents](https://d3js.org/)最好的前端 Data Virualization 开源工具库
# - 建立了一整套数据到SVG属性的计算框架，d3.layout 中包含常用数据可视化模型
# - 运行在JavaScript上，并使用HTML，CSS和SVG
# - 可实现实时交互
# - 入门成本高（斯坦福课程 cs448b-fa18）

# %% [markdown]
# ## [Echarts](https://www.echartsjs.com/)
# - 使用 JavaScript 实现的开源可视化库
# - 中国制造，尤其是对于城市的地理坐标、城市代码等都已经配置好了
# - 可以流畅的运行在 PC 和移动设备上，兼容当前绝大部分浏览器（IE8/9/10/11，Chrome，Firefox，Safari等）
